# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob as glob
# %matplotlib inline

# %% [markdown]
# # 2017 SA Survey

# %%
# %cd 2016
# Out:
# [Errno 2] No such file or directory: '2016'
# /Users/kaichimomose/Desktop/DS-1-Data-Analysis/datasets/SA Feedback Surveys_FINAL/2016

# %%
path = "../2017/Student Feedback Surveys-Superview.csv"
df_2017 = pd.read_csv(path)
df_2017
# Out:
#         ID       Location            Track    Week Rating (Num)  \
# 0      134  San Francisco   Apps, Explorer  Week 1            3
# 1       36    Los Angeles             Apps  Week 1            4
# 2      117  San Francisco            Games  Week 1            4
# 3      253            NaN              NaN  Week 2            4
# 4      350  New York City   Apps, Explorer  Week 1            4
# 5       23   Redwood City             Apps  Week 1            5
# 6       28    Los Angeles             Apps  Week 7            5
# 7       65  San Francisco             Apps  Week 1            5
# 8      101    Santa Clara             Apps  Week 1            5
# 9      124    Santa Clara             Apps  Week 1            5
# 10     157   Redwood City             Apps  Week 2            5
# 11     170        Oakland             Apps  Week 2            5
# 12     255  San Francisco             Apps  Week 2            5
# 13     289  Washington DC             Apps  Week 1            5
# 14     299  Washington DC   Apps, Explorer  Week 1            5
# 15     307            NaN              NaN  Week 3            5
# 16     319   Redwood City             Apps  Week 3            5
# 17     336  New York City             Apps  Week 1            5
# 18     441  San Francisco   Apps, Explorer  Week 3            5
# 19     482    Santa Clara             Apps  Week 3            5
# 20      37    Los Angeles            Games  Week 1            6
# 21      41        Chicago   Apps, Explorer  Week 1            6
# 22      45        Chicago             Apps  Week 1            6
# 23      47        Chicago             Apps  Week 1            6
# 24      77  San Francisco             Apps  Week 1            6
# 25      78  San Francisco             Apps  Week 1            6
# 26      94  San Francisco   Apps, Explorer  Week 1            6
# 27     193    Santa Clara             Apps  Week 2            6
# 28     251  San Francisco   Apps, Explorer  Week 2            6
# 29     254  San Francisco             Apps  Week 2            6
# ...    ...            ...              ...     ...          ...
# 1423  1470  New York City            Games  Week 7           10
# 1424  1471  New York City             Apps  Week 7            8
# 1425  1472  New York City            Games  Week 7            9
# 1426  1473  New York City  Games, Explorer  Week 7           10
# 1427  1474  New York City            Games  Week 7            9
# 1428  1475  New York City             Apps  Week 7            9
# 1429  1476  New York City             Apps  Week 7            8
# 1430  1477  New York City            Games  Week 7           10
# 1431  1478  New York City             Apps  Week 7           10
# 1432  1479  New York City            Games  Week 7            9
# 1433  1480  New York City             Apps  Week 7            9
# 1434  1481  New York City             Apps  Week 7           10
# 1435  1482  New York City             Apps  Week 7            8
# 1436  1483  New York City             Apps  Week 7            7
# 1437  1484  New York City   Apps, Explorer  Week 7            7
# 1438  1485  New York City             Apps  Week 7            7
# 1439  1486  New York City             Apps  Week 7            9
# 1440  1487  New York City             Apps  Week 7            8
# 1441  1488  New York City  Games, Explorer  Week 7            7
# 1442  1489  New York City   Apps, Explorer  Week 7           10
# 1443  1490  New York City   Apps, Explorer  Week 7           10
# 1444  1491  New York City            Games  Week 7            9
# 1445  1492  New York City             Apps  Week 7            9
# 1446  1493  New York City             Apps  Week 7            3
# 1447  1494  New York City  Games, Explorer  Week 7           10
# 1448  1495  New York City   Apps, Explorer  Week 7           10
# 1449  1496  New York City   Apps, Explorer  Week 7            8
# 1450  1497  New York City             Apps  Week 7           10
# 1451  1498  New York City   Apps, Explorer  Week 7            1
# 1452  1499  New York City             Apps  Week 5            8
#
#         Schedule Pacing
# 0            Just right
# 1     A little too fast
# 2          Way too slow
# 3     A little too fast
# 4            Just right
# 5            Just right
# 6            Just right
# 7     A little too slow
# 8     A little too slow
# 9            Just right
# 10           Just right
# 11           Just right
# 12         Way too fast
# 13           Just right
# 14    A little too slow
# 15    A little too slow
# 16           Just right
# 17    A little too slow
# 18           Just right
# 19           Just right
# 20           Just right
# 21           Just right
# 22    A little too slow
# 23    A little too slow
# 24    A little too fast
# 25    A little too fast
# 26           Just right
# 27           Just right
# 28           Just right
# 29         Way too fast
# ...                 ...
# 1423         Just right
# 1424         Just right
# 1425         Just right
# 1426         Just right
# 1427         Just right
# 1428         Just right
# 1429  A little too fast
# 1430         Just right
# 1431         Just right
# 1432         Just right
# 1433         Just right
# 1434         Just right
# 1435         Just right
# 1436  A little too fast
# 1437       Way too fast
# 1438         Just right
# 1439         Just right
# 1440         Just right
# 1441         Just right
# 1442         Just right
# 1443         Just right
# 1444  A little too fast
# 1445         Just right
# 1446         Just right
# 1447         Just right
# 1448         Just right
# 1449         Just right
# 1450         Just right
# 1451  A little too slow
# 1452         Just right
#
# [1453 rows x 6 columns]

# %%
df_2017_week1_LA = df_2017[(df_2017["Week"]=="Week 1") & (df_2017["Location"]=="Los Angeles")]
df_2017_week1_LA
# Out:
#       ID     Location  Track    Week Rating (Num)    Schedule Pacing
# 1     36  Los Angeles   Apps  Week 1            4  A little too fast
# 20    37  Los Angeles  Games  Week 1            6         Just right
# 45    26  Los Angeles   Apps  Week 1            7  A little too fast
# 46    35  Los Angeles   Apps  Week 1            7         Just right
# 104   29  Los Angeles   Apps  Week 1            8  A little too fast
# 105   31  Los Angeles  Games  Week 1            8  A little too fast
# 258   27  Los Angeles  Games  Week 1            9         Just right
# 259   30  Los Angeles   Apps  Week 1            9         Just right
# 260   32  Los Angeles   Apps  Week 1            9  A little too fast
# 261   33  Los Angeles  Games  Week 1            9         Just right
# 382   34  Los Angeles   Apps  Week 1           10         Just right
# 407  149  Los Angeles   Apps  Week 1           10         Just right
# 408  151  Los Angeles   Apps  Week 1           10         Just right
# 409  152  Los Angeles   Apps  Week 1           10         Just right

# %%
# Make Schedule Pacing Integers
schedules = df_2017["Schedule Pacing"]
schedulesKey = {"Just right" : 3, "A little too fast" : 4, "A little too slow" : 2, "Way too slow" : 1, "Way too fast" : 5}
newSchedules = np.array([])

for string in schedules:
    if string in schedulesKey:
        newSchedules = np.append(newSchedules, int(schedulesKey[string]))
    else:
        newSchedules = np.append(newSchedules, None)

schedF = pd.DataFrame(newSchedules)
df_2017["Schedule Pacing"] = schedF

# %%
# Make Weeks Integers
weeks = df_2017["Week"]
newWeeks = np.array([])

for string in weeks:
    newWeeks = np.append(newWeeks, int(string[-1]))

weekDf = pd.DataFrame(newWeeks)
df_2017["Week"] = weekDf
df_2017
# Out:
#         ID       Location            Track  Week Rating (Num) Schedule Pacing
# 0      134  San Francisco   Apps, Explorer   1.0            3               3
# 1       36    Los Angeles             Apps   1.0            4               4
# 2      117  San Francisco            Games   1.0            4               1
# 3      253            NaN              NaN   2.0            4               4
# 4      350  New York City   Apps, Explorer   1.0            4               3
# 5       23   Redwood City             Apps   1.0            5               3
# 6       28    Los Angeles             Apps   7.0            5               3
# 7       65  San Francisco             Apps   1.0            5               2
# 8      101    Santa Clara             Apps   1.0            5               2
# 9      124    Santa Clara             Apps   1.0            5               3
# 10     157   Redwood City             Apps   2.0            5               3
# 11     170        Oakland             Apps   2.0            5               3
# 12     255  San Francisco             Apps   2.0            5               5
# 13     289  Washington DC             Apps   1.0            5               3
# 14     299  Washington DC   Apps, Explorer   1.0            5               2
# 15     307            NaN              NaN   3.0            5               2
# 16     319   Redwood City             Apps   3.0            5               3
# 17     336  New York City             Apps   1.0            5               2
# 18     441  San Francisco   Apps, Explorer   3.0            5               3
# 19     482    Santa Clara             Apps   3.0            5               3
# 20      37    Los Angeles            Games   1.0            6               3
# 21      41        Chicago   Apps, Explorer   1.0            6               3
# 22      45        Chicago             Apps   1.0            6               2
# 23      47        Chicago             Apps   1.0            6               2
# 24      77  San Francisco             Apps   1.0            6               4
# 25      78  San Francisco             Apps   1.0            6               4
# 26      94  San Francisco   Apps, Explorer   1.0            6               3
# 27     193    Santa Clara             Apps   2.0            6               3
# 28     251  San Francisco   Apps, Explorer   2.0            6               3
# 29     254  San Francisco             Apps   2.0            6               5
# ...    ...            ...              ...   ...          ...             ...
# 1423  1470  New York City            Games   7.0           10               3
# 1424  1471  New York City             Apps   7.0            8               3
# 1425  1472  New York City            Games   7.0            9               3
# 1426  1473  New York City  Games, Explorer   7.0           10               3
# 1427  1474  New York City            Games   7.0            9               3
# 1428  1475  New York City             Apps   7.0            9               3
# 1429  1476  New York City             Apps   7.0            8               4
# 1430  1477  New York City            Games   7.0           10               3
# 1431  1478  New York City             Apps   7.0           10               3
# 1432  1479  New York City            Games   7.0            9               3
# 1433  1480  New York City             Apps   7.0            9               3
# 1434  1481  New York City             Apps   7.0           10               3
# 1435  1482  New York City             Apps   7.0            8               3
# 1436  1483  New York City             Apps   7.0            7               4
# 1437  1484  New York City   Apps, Explorer   7.0            7               5
# 1438  1485  New York City             Apps   7.0            7               3
# 1439  1486  New York City             Apps   7.0            9               3
# 1440  1487  New York City             Apps   7.0            8               3
# 1441  1488  New York City  Games, Explorer   7.0            7               3
# 1442  1489  New York City   Apps, Explorer   7.0           10               3
# 1443  1490  New York City   Apps, Explorer   7.0           10               3
# 1444  1491  New York City            Games   7.0            9               4
# 1445  1492  New York City             Apps   7.0            9               3
# 1446  1493  New York City             Apps   7.0            3               3
# 1447  1494  New York City  Games, Explorer   7.0           10               3
# 1448  1495  New York City   Apps, Explorer   7.0           10               3
# 1449  1496  New York City   Apps, Explorer   7.0            8               3
# 1450  1497  New York City             Apps   7.0           10               3
# 1451  1498  New York City   Apps, Explorer   7.0            1               2
# 1452  1499  New York City             Apps   5.0            8               3
#
# [1453 rows x 6 columns]

# %%
# Make Ratings Strings for NPS
ratings = df_2017["Rating (Num)"]
newRatings = np.array([])

for num in ratings:
    if not num == "nan" and not num == "#ERROR!":
        if float(num) > 8:
            newRatings = np.append(newRatings, "Promoter")
        elif float(num) > 6:
            newRatings = np.append(newRatings, "Passive")
        else:
            newRatings = np.append(newRatings, "Detractor")
    else:
        newRatings = np.append(newRatings, "NaN")


ratingDf = pd.DataFrame(newRatings)
df_2017["Rating (Num)"] = ratingDf
df_2017
# Out:
#         ID       Location            Track  Week Rating (Num) Schedule Pacing
# 0      134  San Francisco   Apps, Explorer   1.0    Detractor               3
# 1       36    Los Angeles             Apps   1.0    Detractor               4
# 2      117  San Francisco            Games   1.0    Detractor               1
# 3      253            NaN              NaN   2.0    Detractor               4
# 4      350  New York City   Apps, Explorer   1.0    Detractor               3
# 5       23   Redwood City             Apps   1.0    Detractor               3
# 6       28    Los Angeles             Apps   7.0    Detractor               3
# 7       65  San Francisco             Apps   1.0    Detractor               2
# 8      101    Santa Clara             Apps   1.0    Detractor               2
# 9      124    Santa Clara             Apps   1.0    Detractor               3
# 10     157   Redwood City             Apps   2.0    Detractor               3
# 11     170        Oakland             Apps   2.0    Detractor               3
# 12     255  San Francisco             Apps   2.0    Detractor               5
# 13     289  Washington DC             Apps   1.0    Detractor               3
# 14     299  Washington DC   Apps, Explorer   1.0    Detractor               2
# 15     307            NaN              NaN   3.0    Detractor               2
# 16     319   Redwood City             Apps   3.0    Detractor               3
# 17     336  New York City             Apps   1.0    Detractor               2
# 18     441  San Francisco   Apps, Explorer   3.0    Detractor               3
# 19     482    Santa Clara             Apps   3.0    Detractor               3
# 20      37    Los Angeles            Games   1.0    Detractor               3
# 21      41        Chicago   Apps, Explorer   1.0    Detractor               3
# 22      45        Chicago             Apps   1.0    Detractor               2
# 23      47        Chicago             Apps   1.0    Detractor               2
# 24      77  San Francisco             Apps   1.0    Detractor               4
# 25      78  San Francisco             Apps   1.0    Detractor               4
# 26      94  San Francisco   Apps, Explorer   1.0    Detractor               3
# 27     193    Santa Clara             Apps   2.0    Detractor               3
# 28     251  San Francisco   Apps, Explorer   2.0    Detractor               3
# 29     254  San Francisco             Apps   2.0    Detractor               5
# ...    ...            ...              ...   ...          ...             ...
# 1423  1470  New York City            Games   7.0     Promoter               3
# 1424  1471  New York City             Apps   7.0      Passive               3
# 1425  1472  New York City            Games   7.0     Promoter               3
# 1426  1473  New York City  Games, Explorer   7.0     Promoter               3
# 1427  1474  New York City            Games   7.0     Promoter               3
# 1428  1475  New York City             Apps   7.0     Promoter               3
# 1429  1476  New York City             Apps   7.0      Passive               4
# 1430  1477  New York City            Games   7.0     Promoter               3
# 1431  1478  New York City             Apps   7.0     Promoter               3
# 1432  1479  New York City            Games   7.0     Promoter               3
# 1433  1480  New York City             Apps   7.0     Promoter               3
# 1434  1481  New York City             Apps   7.0     Promoter               3
# 1435  1482  New York City             Apps   7.0      Passive               3
# 1436  1483  New York City             Apps   7.0      Passive               4
# 1437  1484  New York City   Apps, Explorer   7.0      Passive               5
# 1438  1485  New York City             Apps   7.0      Passive               3
# 1439  1486  New York City             Apps   7.0     Promoter               3
# 1440  1487  New York City             Apps   7.0      Passive               3
# 1441  1488  New York City  Games, Explorer   7.0      Passive               3
# 1442  1489  New York City   Apps, Explorer   7.0     Promoter               3
# 1443  1490  New York City   Apps, Explorer   7.0     Promoter               3
# 1444  1491  New York City            Games   7.0     Promoter               4
# 1445  1492  New York City             Apps   7.0     Promoter               3
# 1446  1493  New York City             Apps   7.0    Detractor               3
# 1447  1494  New York City  Games, Explorer   7.0     Promoter               3
# 1448  1495  New York City   Apps, Explorer   7.0     Promoter               3
# 1449  1496  New York City   Apps, Explorer   7.0      Passive               3
# 1450  1497  New York City             Apps   7.0     Promoter               3
# 1451  1498  New York City   Apps, Explorer   7.0    Detractor               2
# 1452  1499  New York City             Apps   5.0      Passive               3
#
# [1453 rows x 6 columns]

# %%
def calNps(dataframe):
    npsScores = []
    for i in range(1,9):
        df_each_week = dataframe[dataframe["Week"] == i]
        promotersAmount = df_each_week[df_each_week["Rating (Num)"] == "Promoter"].size
        detractorsAmount = df_each_week[df_each_week["Rating (Num)"] == "Detractor"].size
        passiveAmount = df_each_week[df_each_week["Rating (Num)"] == "Passive"].size
        nps = (promotersAmount - detractorsAmount) / (promotersAmount + detractorsAmount + passiveAmount)
        npsScores = np.append(npsScores, nps * 100)
    return npsScores

# %%
def calave(dataframe):
    pacing_ave = []
    for i in range(1, 9):
        df_each_week = dataframe[dataframe["Week"]==i]
        mean = np.mean(df_each_week["Schedule Pacing"])
        pacing_ave = np.append(pacing_ave, mean)
    return pacing_ave

# %%
means = calave(df_2017)
npsScores = calNps(df_2017)
TNR = {"Week": [], "Satisfaction": [], "NPS" : []}
for i in range(1,9):
    TNR["NPS"].append(npsScores[i-1])
    TNR["Satisfaction"].append(means[i-1])
    TNR["Week"].append(i)
TNR = pd.DataFrame(TNR)
TNR.plot(x="Week", y="NPS", title="Change in NPS in Weeks in 2017")
plt.xlim(1,8)
plt.ylim(-100,100)
# Out:
# (-100, 100)

# %%
TNR.plot(x="Week", y="Satisfaction", title="change in pacing satisfaction in weeks in 2017")
plt.xlim(1,8)
plt.ylim(0,5)

# %% [markdown]
# # 2016 Summer Academy Survey

# %%
# Combine the CSV Files together in one Dataframe
list_all_week =[]

for i in range(1,8):
    list_file = []
    city = ""
    for name in glob.glob('./Anon Week ' + str(i) + "*"):
        city = name[-6:-4]
        df = pd.read_csv(name)
        if city == "re" or city == 'SG':
            city = "Singapore"
        elif city == "yo":
            city = "Tokyo"
        elif city == "ei":
            city = "Taipei"
        elif city == 'LA':
            city = 'Los Angeles'
        elif city == 'SF':
            city = "San Francisco"
        elif city == 'NY':
            city = 'New York City'
        elif city == 'SV':
            city = 'Sunnyvale'
        elif city == 'HK':
            city = 'Hong Kong'
        df["Location"] = city
        list_file.append(df)
    df_2016 = pd.concat(list_file)
    df_2016["Week"] = i
    list_all_week.append(df_2016)
df_2016 = pd.concat(list_all_week)
df_2016

# %%
# Combine Pacing Columns together
paces = df_2016[["How well are the tutorials paced?", "How well is the schedule paced?"]]
paces = paces["How well are the tutorials paced?"].fillna(paces["How well is the schedule paced?"])
new_paces = []
for pace in paces:
    if not pace == "#REF!":
        new_paces.append(pace)
    else:
        new_paces.append("NaN")
df_2016 = df_2016.drop("How well are the tutorials paced?", 1)
df_2016 = df_2016.drop("How well is the schedule paced?", 1)
df_2016["Schedule Pacing"] = new_paces

# %%
df_2016 = df_2016.drop("Timestamp", 1)
df_2016 = df_2016.drop("Unnamed: 0", 1)
df_2016 = df_2016.rename(columns = {"How would you rate your overall satisfaction with the Summer Academy this week?" : "Rating (Num)", "What track are you in?" : "Track"})

# %%
def nps_rating(number_rating):
    newRatings = np.array([])

    for num in number_rating:
        if not num == "#REF!":
            if float(num) > 4:
                newRatings = np.append(newRatings, "Promoter")
            elif float(num) > 3:
                newRatings = np.append(newRatings, "Passive")
            else:
                newRatings = np.append(newRatings, "Detractor")
        else:
            newRatings = np.append(newRatings, "NaN")
    nps_ratingDf = pd.DataFrame(newRatings)
    return nps_ratingDf

# %%
ratings = df_2016["Rating (Num)"]
df_2016["Rating (Num)"] = nps_rating(ratings)
df_2016

# %%
path = "Week 8 Feedback (2016, incomplete) - results.csv"
df_2016_week8 = pd.read_csv(path)
df_2016_week8

# %%
df_2016_week8 = df_2016_week8.drop("Start Date (UTC)", 1)
df_2016_week8 = df_2016_week8.drop("Submit Date (UTC)", 1)
df_2016_week8 = df_2016_week8.drop("#", 1)
df_2016_week8 = df_2016_week8.drop("Network ID", 1)
df_2016_week8 = df_2016_week8.rename(columns={"How likely is it that you would recommend the Make School Summer Academy to a friend?" : 'Rating (Num)'})
df_2016_week8 = df_2016_week8.rename(columns={"location" : 'Location'})
df_2016_week8 = df_2016_week8.rename(columns={"track" : 'Track'})
df_2016_week8["Week"] = 8
df_2016_week8["Schedule Pacing"] = np.nan

# %%
tracks = df_2016_week8['Track']
for i in range(len(tracks)):
    tracks[i] = tracks[i].replace("summer", '')
df_2016_week8['Track'] = tracks

# %%
df_2016_week8 = df_2016_week8.sort_values(['Location', 'Track'], ascending=[1, 1])

# %%
ratings = df_2016_week8["Rating (Num)"]
df_2016_week8["Rating (Num)"] = nps_rating(ratings)
df_2016_week8

# %%
df_2016=df_2016.append(df_2016_week8)
df_2016

# %%
def calNps_2016():
    npsScores = []
    for i in range(1,9):
        df_each_week = df_2016[df_2016["Week"] == i]
        promotersAmount = df_each_week[df_each_week["Rating (Num)"] == "Promoter"].size
        detractorsAmount = df_each_week[df_each_week["Rating (Num)"] == "Detractor"].size
        passiveAmount = df_each_week[df_each_week["Rating (Num)"] == "Passive"].size
        nps = (promotersAmount - detractorsAmount) / (promotersAmount + detractorsAmount + passiveAmount)
        npsScores = np.append(npsScores, nps * 100)
    return npsScores

# %%
def calave_2016():
    pacing_ave = []
    for i in range(1, 9):
        df_each_week = df_2016[df_2016["Week"]==i]
        mean = np.mean(df_each_week["Schedule Pacing"])
        pacing_ave = np.append(pacing_ave, mean)
    return pacing_ave

# %%
# means = calave_2016()
npsScores = calNps_2016()
TNR_2016 = {"Week": [], "NPS" : []}
for i in range(1,9):
    TNR_2016["NPS"].append(npsScores[i-1])
#     TNR["Satisfaction"].append(means[i-1])
    TNR_2016["Week"].append(i)
TNR_2016 = pd.DataFrame(TNR_2016)
TNR_2016.plot(x="Week", y="NPS", title="Change in NPS in Weeks in 2016")
plt.xlim(1,8)
plt.ylim(-100,100)

# %%
# Combine the Years together!
df_2016["Year"] = 2016
df_2017["Year"] = 2017
df_total = df_2016.append(df_2017)
df_total

# %%
df_San_francisco = df_total[(df_total["Location"] == "San Francisco")]
df_2016_San_francisco = df_San_francisco[(df_San_francisco["Year"] == 2016)]
df_2017_San_francisco = df_San_francisco[(df_San_francisco["Year"] == 2017)]

# %%
npsScores_SF_2016 = calNps(df_2016_San_francisco)
npsScores_SF_2017 = calNps(df_2017_San_francisco)
TNR = {"Week": [], "2016" : [], "2017" : []}
for i in range(1,9):
    TNR["2016"].append(npsScores_SF_2016[i-1])
    TNR["2017"].append(npsScores_SF_2017[i-1])
    TNR["Week"].append(i)
TNR = pd.DataFrame(TNR)
TNR.plot(x="Week", y=["2016", "2017"], title="Change in NPS in Weeks in 2016 and 2017 in SF")
plt.xlim(1,8)
plt.ylim(-100,100)
plt.show()

# %%
% cd ..
# Out:
# /Users/kaichimomose/Desktop/DS-1-Data-Analysis/datasets
